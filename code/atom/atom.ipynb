# %% [markdown]
# # Import Modules

# %%
from numpy    import *
from pyatomdb import *

# %% [markdown]
# # Load Si01 Level

# %%
Si01_Level = atomdb.get_data(14,14,"IR")
Si01_Level[1].data.names
# Out:
# ['ELEMENT',
#  'ION_INIT',
#  'ION_FINAL',
#  'LEVEL_FINAL',
#  'LEVEL_INIT',
#  'TR_TYPE',
#  'TR_INDEX',
#  'PAR_TYPE',
#  'MIN_TEMP',
#  'MAX_TEMP',
#  'TEMPERATURE',
#  'IONREC_PAR',
#  'WAVELEN',
#  'WAVE_OBS',
#  'WAVE_ERR',
#  'BR_RATIO',
#  'BR_RAT_ERR',
#  'LABEL',
#  'RATE_REF',
#  'WAVE_REF',
#  'WV_OBS_REF',
#  'BR_RAT_REF']

# %%
Si01_Level[1].data
# Out:
# FITS_rec([(14, 14, 15,   1, 1, 'CI',   1, 118, 446700., 1.00e+09, [1.020e-02, 5.000e-02, 1.000e-01, 1.500e-01, 2.000e-01, 2.500e-01, 3.000e-01, 3.500e-01, 4.000e-01, 4.500e-01, 5.000e-01, 5.500e-01, 6.000e-01, 6.500e-01, 7.000e-01, 7.500e-01, 8.000e-01, 8.038e-01, 0.000e+00, 0.000e+00], [2.86820000e-06, 2.82980000e-06, 2.82490009e-06, 2.83899999e-06, 2.86060003e-06, 2.88420006e-06, 2.90859998e-06, 2.93259995e-06, 2.95609993e-06, 2.97909992e-06, 3.00250008e-06, 3.02779995e-06, 3.05899994e-06, 3.10430005e-06, 3.18720004e-06, 3.37119991e-06, 3.87460022e-06, 3.95090001e-06, 0.00000000e+00, 0.00000000e+00], nan, nan, nan, nan, nan, 'nan', '2007A&A...466..771D', '', '', ''),
# ...
