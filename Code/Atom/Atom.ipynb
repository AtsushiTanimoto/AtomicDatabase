# %% [markdown]
# # Import Modules

# %%
from numpy    import *
from pyatomdb import *

# %% [markdown]
# # Load Si01 Level

# %%
Si01_Recombination = atomdb.get_ionrec_rate(Te_in=logspace(5,10,100), Z=14, z1=14)[1]
Si01_Recombination
# Out:
# array([4.33585480e-11, 4.02431284e-11, 3.73437005e-11, 3.46456521e-11,
#        3.21353334e-11, 2.97999961e-11, 2.76277368e-11, 2.56074434e-11,
#        2.37287446e-11, 2.19819621e-11, 2.03580665e-11, 1.88486347e-11,
#        1.74458110e-11, 1.61422697e-11, 1.49311805e-11, 1.38061760e-11,
#        1.27613209e-11, 1.17910836e-11, 1.08903090e-11, 1.00541939e-11,
#        9.27826296e-12, 8.55834683e-12, 7.89056160e-12, 7.27128947e-12,
#        6.69716066e-12, 6.16503664e-12, 5.67199427e-12, 5.21531116e-12,
#        4.79245188e-12, 4.40105510e-12, 4.03892161e-12, 3.70400314e-12,
#        3.39439190e-12, 3.10831085e-12, 2.84410459e-12, 2.60023092e-12,
#        2.37525297e-12, 2.16783177e-12, 1.97671952e-12, 1.80075315e-12,
#        1.63884843e-12, 1.48999447e-12, 1.35324864e-12, 1.22773176e-12,
#        1.11262381e-12, 1.00715977e-12, 9.10625886e-13, 8.22356196e-13,
#        7.41729282e-13, 6.68165298e-13, 6.01123221e-13, 5.40098306e-13,
# ...
