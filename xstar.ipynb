        Ion           += [Integer[Pointer[10*n+8]+4]]
        E             += [Electron[Integer[Pointer[10*n+8]+4]]]
        Level         += [Integer[Pointer[10*n+8]+3]]
        N             += [Integer[Pointer[10*n+8]-1]]
        L             += [Integer[Pointer[10*n+8]+1]]
        S             += [Integer[Pointer[10*n+8]+0]]
        J             += [int(Real[Pointer[10*n+7]+0])]
        Energy        += ["{0:.6e}".format(Real[Pointer[10*n+7]-1])]
        Potential     += ["{0:.6e}".format(Real[Pointer[10*n+7]+2])]
        Configuration += ["".join(list(map(chr,String[Pointer[10*n+9]-1:Pointer[10*n+19]-1])))]

df01 = DataFrame(data={"Z":Z, "Ion":Ion, "Electron":E, "Level":Level, "N":N, "L":L, "2S+1":S, "2J+1":J, "Energy":Energy, "Potential":Potential, "Configuration":Configuration})
df01
# Out:
#         Z  Ion  Electron  Level   N  L  2S+1  2J+1        Energy  \
# 0       1    1         1      1   1  0     2     2  0.000000e+00
# 1       1    1         1      2   2  1     2     2  1.019881e+01
# 2       1    1         1      3   2  1     2     4  1.019873e+01
# 3       1    1         1      4   2  0     2     2  1.019881e+01
# 4       1    1         1      5   3  1     2     2  1.208750e+01
# ...    ..  ...       ...    ...  .. ..   ...   ...           ...
# 17629  30  465         1     29   6  3     2    14  1.204410e+04
# 17630  30  465         1     30   6  4     2    18  1.204410e+04
# 17631  30  465         1     31   6  5     2    22  1.204410e+04
# 17632  30  465         1     32  12  0     2     1  1.230220e+04
# 17633  30  465         1     33   1  0     1     1  1.238820e+04
#
#           Potential   Configuration
# 0      1.360000e+01      1s1.2S_1/2
# 1      1.360000e+01  1s0.2p1.2P_1/2
# 2      1.360000e+01  1s0.2p1.2P_3/2
# 3      1.360000e+01  1s0.2s1.2S_1/2
# ...

# %% [markdown]
# ## Save Level Data

# %%
for n in range(92,106):
    df01.query("Ion=={0:02d}".format(n)).to_csv("./xstar_database/Si/Si{0:02d}_Level.tsv".format(106-n),sep="\t")
for n in range(326,352):
    df01.query("Ion=={0:02d}".format(n)).to_csv("./xstar_database/Fe/Fe{0:02d}_Level.tsv".format(352-n),sep="\t")

# %% [markdown]
# # Spectroscopic Level Photoionization

# %% [markdown]
# ## Load Spectroscopic Level Photoionization

# %%
Z             = []
Initial_Ion   = []
Initial_Level = []
Final_Ion     = []
Final_Level   = []
N             = []
L             = []
J             = []
Energy        = []
Cross         = []

for i in range(390628):
    if Pointer[10*i+1]==49 or Pointer[10*i+1]==53:
        for j in range(Pointer[10*i+4]//2):
            Z             += [Integer[Pointer[10*i+8]+2]]
            Initial_Ion   += [Integer[Pointer[10*i+8]+6]]
            Initial_Level += [Integer[Pointer[10*i+8]+5]]
            Final_Ion     += [Integer[Pointer[10*i+8]+4]]
            Final_Level   += [Integer[Pointer[10*i+8]+3]]
            N             += [Integer[Pointer[10*i+8]-1]]
            L             += [Integer[Pointer[10*i+8]+0]]
            J             += [Integer[Pointer[10*i+8]+1]]
            Energy        += ["{0:.6e}".format(Real[Pointer[10*i+7]+2*j-1])]
            Cross         += ["{0:.6e}".format(Real[Pointer[10*i+7]+2*j+0])]

df02 = DataFrame(data={"Z":Z,"Initial Ion":Initial_Ion,"Initial Level":Initial_Level,"Final Ion":Final_Ion, "Final Level": Final_Level, "N": N, "L": L, "2J": J, "Energy (Ry)": Energy, "Cross Section (Mb)": Cross})
df02 = df02.sort_values(["Initial Ion","Initial Level"]).reset_index().drop(columns="index")
df02

# %% [markdown]
# # Bound-bound Radiative

# %% [markdown]
# ## Load Bound-bound Radiative

# %%
Z             = []
Ion           = []
Initial_Level = []
Final_Level   = []
Energy        = []
Strength      = []
A_coefficient = []

for n in range(390628):
    if Pointer[10*n+1]==50:
        if Real[Pointer[10*n+7]-1]!=0:
            Z             += [Integer[Pointer[10*n+8]+1]]
            Ion           += [Integer[Pointer[10*n+8]+2]]
            Initial_Level += [Integer[Pointer[10*n+8]+0]]
            Final_Level   += [Integer[Pointer[10*n+8]-1]]
            Energy        += ["{0:.6e}".format(12398/Real[Pointer[10*n+7]-1])]
            Strength      += ["{0:.6e}".format(      Real[Pointer[10*n+7]+0])]
            A_coefficient += ["{0:.6e}".format(      Real[Pointer[10*n+7]+1])]

df03 = DataFrame(data={"Z":Z, "Ion":Ion, "Initial Level":Initial_Level, "Final Level":Final_Level, "Energy (eV)":Energy, "Oscillator Strength":Strength, "A Coefficient":A_coefficient})
df03 = df03.sort_values(["Ion","Initial Level","Final Level"]).reset_index().drop(columns="index")
df03
# Out:
#         Z  Ion  Initial Level  Final Level   Energy (eV) Oscillator Strength  \
# 0       1    1              2            1  1.019846e+01        0.000000e+00
# 1       1    1              3            1  1.019838e+01        0.000000e+00
# 2       1    1              5            1  1.208708e+01        0.000000e+00
# 3       1    1              5            4  1.888619e+00        0.000000e+00
# 4       1    1              6            1  1.208710e+01        0.000000e+00
# ...    ..  ...            ...          ...           ...                 ...
# 227945  1  465             30           16  4.210394e+02        0.000000e+00
# 227946  1  465             30           22  1.458263e+02        0.000000e+00
# 227947  1  465             30           23  1.454324e+02        0.000000e+00
# 227948  1  465             31           24  1.454331e+02        0.000000e+00
# 227949  1  465             31           25  1.451975e+02        0.000000e+00
#
#        A Coefficient
# 0       6.265030e+08
# ...

# %% [markdown]
# ## Save Bound-bound Radiative

# %%
for n in range(92,106):
    df03.query("Ion=={0:02d}".format(n)).to_csv("./xstar_database/Si/Si{0:02d}_Transition.tsv".format(106-n),sep="\t")

# %% [markdown]
# # Superlevel Photoionization

# %% [markdown]
# ## Load Superlevel Photoionization

# %%
Z             = []
Initial_Ion   = []
Initial_Level = []
Final_Ion     = []
Final_Level   = []
N             = []
L             = []
S             = []
Energy        = []
Cross         = []

for i in range(390628):
    if Pointer[10*i+1]==70 or Pointer[10*i+1]==99:
        nd = Integer[Pointer[10*i+8]-1]
        nt = Integer[Pointer[10*i+8]+0]
        nx = Integer[Pointer[10*i+8]+1]

        for j in range(nx):
            Z             += [Integer[Pointer[10*i+8]+5]]
            Initial_Ion   += [Integer[Pointer[10*i+8]+9]]
            Initial_Level += [Integer[Pointer[10*i+8]+8]]
            Final_Ion     += [Integer[Pointer[10*i+8]+7]]
            Final_Level   += [Integer[Pointer[10*i+8]+6]]
            N             += [Integer[Pointer[10*i+8]+2]]
            L             += [Integer[Pointer[10*i+8]+3]]
            S             += [Integer[Pointer[10*i+8]+4]]
            Energy        += ["{0:.6e}".format(Real[Pointer[10*i+7]+nd+nt+nd*nt+2*j-1])]
            Cross         += ["{0:.6e}".format(Real[Pointer[10*i+7]+nd+nt+nd*nt+2*j+0])]

df04 = DataFrame(data={"Z":Z, "Initial_Ion":Initial_Ion, "Initial Level":Initial_Level, "Final_Ion":Final_Ion, "Final Level":Final_Level, "N":N, "L":L, "2S+1":S, "Energy (Ry)":Energy, "Cross Section (Mb)":Cross})
df04 = df04.sort_values(["Initial_Ion", "Initial Level", "Final Level"]).reset_index().drop(columns="index")
df04
# Out:
#        Z  Initial_Ion  Initial Level  Final_Ion  Final Level   N  L  2S+1  \
# 0      1            1             32          0            1  12  0     2
# 1      1            1             32          0            1  12  0     2
# 2      1            1             32          0            1  12  0     2
# 3      1            1             32          0            1  12  0     2
# 4      1            1             32          0            1  12  0     2
# ...   ..          ...            ...        ...          ...  .. ..   ...
# 21206  1          465             32          0            1  12  0     2
# 21207  1          465             32          0            1  12  0     2
# 21208  1          465             32          0            1  12  0     2
# 21209  1          465             32          0            1  12  0     2
# 21210  1          465             32          0            1  12  0     2
#
#         Energy (Ry) Cross Section (Mb)
# 0      0.000000e+00       1.842000e+02
# ...

# %% [markdown]
# ## Save Superlevel Photoionization

# %%
for n in range(92,106):
    df04.query("Final_Ion=={0:02d}".format(n)).to_csv("./xstar_database/Si/Si{0:02d}_Superlevel_Photoionization.tsv".format(106-n),sep="\t")

# %% [markdown]
# # Superlevel Recombination

# %% [markdown]
# ## Load Superlevel Recombination

# %%
Z             = []
Initial_Ion   = []
Initial_Level = []
Final_Ion     = []
Final_Level   = []
N             = []
L             = []
S             = []
Temperature   = []
Rate          = []

for i in range(390628):
    if Pointer[10*i+1]==70:
        nd = Integer[Pointer[10*i+8]-1]
        nt = Integer[Pointer[10*i+8]+0]
        nx = Integer[Pointer[10*i+8]+1]
        
        for j in range(nt):
            Z             += [Integer[Pointer[10*i+8]+5]]
            Initial_Ion   += [Integer[Pointer[10*i+8]+7]]
            Initial_Level += [Integer[Pointer[10*i+8]+6]]
            Final_Ion     += [Integer[Pointer[10*i+8]+9]]
            Final_Level   += [Integer[Pointer[10*i+8]+8]]
            N             += [Integer[Pointer[10*i+8]+2]]
            L             += [Integer[Pointer[10*i+8]+3]]
            S             += [Integer[Pointer[10*i+8]+4]]
            Temperature   += ["{0:.6e}".format(8.61734*10**(-5)*10**(Real[Pointer[10*i+7]+nd+j-1]))]
            Rate          += ["{0:.6e}".format(                 10**(Real[Pointer[10*i+7]+nd+nt+j-1]))]

df05 = DataFrame(data={"Z":Z, "Initial_Ion":Initial_Ion, "Initial Level":Initial_Level, "Final_Ion":Final_Ion, "Final Level":Final_Level, "N":N, "L":L, "2S+1":S, "Temperature (eV)":Temperature, "Rate":Rate})
df05 = df05.sort_values(["Z", "Initial_Ion", "Initial Level", "Final_Ion"]).reset_index().drop(columns="index")
df05.query("Final_Ion==105")[:20]
# Out:
#        Z  Initial_Ion  Initial Level  Final_Ion  Final Level   N  L  2S+1  \
# 6042  14            0              1        105           32  12  0     2
# 6043  14            0              1        105           32  12  0     2
# 6044  14            0              1        105           32  12  0     2
# 6045  14            0              1        105           32  12  0     2
# 6046  14            0              1        105           32  12  0     2
#
#      Temperature (eV)          Rate
# 6042     8.617340e-02  4.442221e-10
# 6043     1.689170e+01  9.484190e-12
# 6044     1.689170e+02  1.042317e-12
# 6045     1.689170e+03  6.807696e-14
# 6046     8.617340e+03  7.447315e-15

# %% [markdown]
# ## Save Superlevel Recombination

# %%
for n in range(92,106):
    df05.query("Final_Ion=={0:02d}".format(n)).to_csv("./xstar_database/Si/Si{0:02d}_Superlevel_Recombination.tsv".format(106-n), sep="\t")

# %% [markdown]
# # Superlevel-bound Radiative

# %% [markdown]
# ## Define Superlevel-bound Radiative

# %%
Z = []
Ion = []
Initial_Level = []
Final_Level = []
Wavelength = []
Density = []
Temperature = []
A_coefficient = []

for i in range(390628):
    if Pointer[10*i+1]==71:
        nd = Integer[Pointer[10*i+8]-1]
        nt = Integer[Pointer[10*i+8]+0]

        for j in range(nt):
            for k in range(nd):
                Z.append(Integer[Pointer[10*i+8]+3])
                Ion.append(Integer[Pointer[10*i+8]+4])
                Initial_Level.append(Integer[Pointer[10*i+8]+2])
                Final_Level.append(Integer[Pointer[10*i+8]+1])
                Wavelength.append("{0:.6e}".format(Real[Pointer[10*i+7]+nd+nt+nd*nt-1]))
                Density.append("{0:.6e}".format(Real[Pointer[10*i+7]+k-1]))
                Temperature.append("{0:.6e}".format(Real[Pointer[10*i+7]+nd+j-1]))
                A_coefficient.append("{0:.6e}".format(Real[Pointer[10*i+7]+nd+nt+(j+1)*(k+1)-2]))

df06 = DataFrame(data={"Z": Z, "Ion": Ion, "Initial Level": Initial_Level, "Final Level": Final_Level, "Wavelength (A)": Wavelength, "Density": Density, "Temperature": Temperature, "Einstein A Coefficient": A_coefficient})

# %% [markdown]
# ## Sort Superlevel-bound Radiative

# %%
dfs06 = df06.sort_values(["Ion", "Initial Level", "Final Level"])
dfs06 = dfs06.reset_index()
dfs06 = dfs06.drop(columns="index")
dfs06
# Out:
#         Z  Ion  ...   Temperature  Einstein A Coefficient
# 0       1    1  ...  3.000000e+00            2.586080e+00
# 1       1    1  ...  3.000000e+00            3.322080e+00
# 2       1    1  ...  3.000000e+00            3.869590e+00
# 3       1    1  ...  3.000000e+00            2.549620e+00
# 4       1    1  ...  3.000000e+00            3.284990e+00
# ...    ..  ...  ...           ...                     ...
# 130850  1  465  ...  5.000000e+00            9.814580e+00
# 130851  1  465  ...  5.000000e+00            1.010820e+01
# 130852  1  465  ...  5.000000e+00            1.030990e+01
# 130853  1  465  ...  5.000000e+00            1.026120e+01
# 130854  1  465  ...  5.000000e+00            9.291770e+00
#
# [130855 rows x 8 columns]

# %% [markdown]
# ## Preserve Superlevel-bound Radiative

# %%
dfs06.to_csv("/content/drive/MyDrive/Monaco/Database/Superlevel-bound_Radiative.tsv", sep="\t")

# %% [markdown]
# # Autoionization Rates

# %% [markdown]
# ## Define Autoionization Rates

# %%
Z = []
Ion = []
Initial_Level = []
Final_Level = []
L = []
S = []
J = []
Energy = []
Rate = []
Configuration = []

for n in range(390628):
    if Pointer[10*n+1]==72:
        Z.append(Integer[Pointer[10*n+8]+3])
        Ion.append(Integer[Pointer[10*n+8]+4])
        Initial_Level.append(Integer[Pointer[10*n+8]+1])
        Final_Level.append(Integer[Pointer[10*n+8]+2])
        L.append(Integer[Pointer[10*n+8]+0])
        S.append(Integer[Pointer[10*n+8]-1])
        J.append(int(Real[Pointer[10*n+7]+1]))
        Rate.append("{0:.6e}".format(Real[Pointer[10*n+7]-1]))
        Energy.append("{0:.6e}".format(Real[Pointer[10*n+7]+0]))
        Configuration.append("".join(list(map(chr, String[Pointer[10*n+9]-1:Pointer[10*n+19]-1]))))

df07 = DataFrame(data={"Z": Z, "Ion": Ion, "Initial Level": Initial_Level, "Final Level": Final_Level, "L": L, "2S+1": S, "2J+1": J, "Energy": Energy, "Rate": Rate, "Configuration": Configuration})
df07
# Out:
#      Z  Ion  Initial Level  ...        Energy          Rate  Configuration
# 0    6   20             50  ...  2.637240e+02  3.470000e+14       2s.2s.1S
# 1    6   20             51  ...  2.731400e+02  2.020000e+14       2s.2p.1P
# 2    6   20             52  ...  2.653970e+02  1.350000e+13       2s.2p.3P
# 3    6   20             53  ...  2.777020e+02  1.430000e+13       2p.2p.1S
# 4    6   20             54  ...  2.723660e+02  3.730000e+14       2p.2p.1D
# ..  ..  ...            ...  ...           ...           ...            ...
# 58  26  350             45  ...  4.732000e+03  1.950000e+14       2s.2p.1P
# 59  26  350             46  ...  4.683670e+03  1.590000e+13       2s.2p.3P
# 60  26  350             47  ...  4.766970e+03  3.880000e+13       2p.2p.1S
# 61  26  350             48  ...  4.728300e+03  2.520000e+14       2p.2p.1D
# 62  26  350             49  ...  4.711630e+03  6.760000e+13       2p.2p.3P
#
# [63 rows x 10 columns]

# %% [markdown]
# ## Preserve Autoionization Rate

# %%
for n in range(92,106):
    df07.query("Ion=={0:02d}".format(n)).to_csv("/content/drive/MyDrive/Monaco/Database/Si{0:02d}_Autoionization.tsv".format(106-n), sep="\t")
